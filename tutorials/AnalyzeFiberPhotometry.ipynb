# %%
import os
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt 
from mimo_pack.fileio.doric import load_doric_xr
from mimo_pack.preprocess.fiber_photometry import correct_fp_signal
from mimo_pack.plot.timeseries import stacked_lines

# %% [markdown]
# ## Using mimopack functions

# %%
#data_path = os.path.join('..', 'test_data', '2025-07-18_030_M1-cM1_0000_124254167.doric')
data_path = os.path.join('..', 'test_data', '25-07-25_D30_Test.doric')
data_xr, pow_xr, dio_xr = load_doric_xr(data_path)
data_fp = correct_fp_signal(data_xr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 #data_path = os.path.join('..', 'test_data', '2025-07-18_030_M1-cM1_0000_124254167.doric')
#       2 data_path = os.path.join('..', 'test_data', '25-07-25_D30_Test.doric')
# ----> 3 data_xr, pow_xr, dio_xr = load_doric_xr(data_path)
#       4 data_fp = correct_fp_signal(data_xr)
#
# File d:\eegtms\mimo_pack\fileio\doric.py:41, in load_doric_xr(doric_file_path)
#      13 """
#      14 Reads a Doric file and converts it into an xarray.DataArray.
#      15
#    (...)
#      38 Initial code generated with Gemini
#      39 """
#      40 # Load the Doric file using the h5py library
# ---> 41 data = h5py.File(doric_file_path, 'r')
#      43 # Extract the relevant datasets from the Doric file
#      44 data = get_h5_hierarchy(data)
#
# File c:\Users\dbh60\.conda\envs\mimo_env\lib\site-packages\h5py\_hl\files.py:564, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     555     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     556                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     557                      alignment_threshold=alignment_threshold,
#     558                      alignment_interval=alignment_interval,
#     559                      meta_block_size=meta_block_size,
#     560                      **kwds)
#     561     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     562                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                      fs_page_size=fs_page_size)
# --> 564     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     566 if isinstance(libver, tuple):
#     567     self._libver = libver
#
# File c:\Users\dbh60\.conda\envs\mimo_env\lib\site-packages\h5py\_hl\files.py:238, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236     if swmr and swmr_support:
#     237         flags |= h5f.ACC_SWMR_READ
# --> 238     fid = h5f.open(name, flags, fapl=fapl)
#     239 elif mode == 'r+':
#     240     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '..\test_data\25-07-25_D30_Test.doric', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
fig, ax = plt.subplots(figsize=(15, 4))
stacked_lines(data_fp.to_numpy(), data_fp.time.to_numpy(),  
              labels=data_fp.channel.values, ax=ax)
# Out:
# <Axes: >
